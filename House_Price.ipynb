# %% [markdown]
# <a href="https://colab.research.google.com/github/navneet23341/titanic-ml-project/blob/main/House_Price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/Datasets/House_price/train.csv")

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df['MSSubClass'].isna().sum()
# Out:
# np.int64(0)

# %%
df['MSZoning'].isna().sum()
# Out:
# np.int64(0)

# %%
df['LotFrontage'].isna().sum()
# Out:
# np.int64(259)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df['LotFrontage'].describe()
sns.histplot(data= df['LotFrontage'] , bins= 100)
plt.show()

# %%
df['LotFrontage'] = df['LotFrontage'].fillna(df['LotFrontage'].median())

# %%
sns.histplot(data= df['LotFrontage'] , bins= 100)
plt.show()

# %%
df_original = df.copy()

# %%
df['Alley'] = df['Alley'].fillna("NA")

# %%
df['MasVnrType'] = df['MasVnrType'].fillna("None")

# %%
df['MasVnrArea'] = df['MasVnrArea'].fillna(0)

# %%
df['BsmtQual'] = df['BsmtQual'].fillna("NA")

# %%
df['BsmtCond'] = df['BsmtCond'].fillna("NA")

# %%
df['BsmtExposure'] = df['BsmtExposure'].fillna("NA")

# %%
df['BsmtFinType1'] = df['BsmtFinType1'].fillna("NA")

# %%
df['BsmtFinType2'] = df['BsmtFinType2'].fillna("NA")

# %%
df['Electrical'] = df['Electrical'].fillna("Unknown")

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df['FireplaceQu'] = df['FireplaceQu'].fillna("NA")

# %%
df['GarageType'] = df['GarageType'].fillna("NA")

# %%
df['GarageFinish'] = df['GarageFinish'].fillna("NA")

# %%
df['GarageQual'] = df['GarageQual'].fillna("NA")

# %%
df['GarageCond'] = df['GarageCond'].fillna("NA")

# %%
df['PoolQC'] = df['PoolQC'].fillna("NA")

# %%
df['Fence'] = df['Fence'].fillna("NA")

# %%
df['MiscFeature'] = df['MiscFeature'].fillna("NA")

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df['GarageYrBlt'].isna().sum()
# Out:
# np.int64(81)

# %% [markdown]
# General

# %%
df.groupby('MSSubClass')['MSSubClass'].value_counts()
# Out:
# MSSubClass
# 20     536
# 30      69
# 40       4
# 45      12
# 50     144
# 60     299
# 70      60
# 75      16
# 80      58
# 85      20
# 90      52
# 120     87
# 160     63
# 180     10
# 190     30
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x=df['MSSubClass'])
plt.show()

# %%
df.groupby('MSZoning')['MSZoning'].value_counts()
# Out:
# MSZoning
# C (all)      10
# FV           65
# RH           16
# RL         1151
# RM          218
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x= df['MSZoning'])
plt.show()

# %%
sns.histplot(data=df,x=df['LotFrontage'])
plt.show()

# %%
print(df.groupby('LotArea')['LotArea'].value_counts())
sns.histplot(data=df , x=df['LotArea'], bins= 100)
plt.show()
# Out:
# LotArea
# 1300      1
# 1477      1
# 1491      1
# 1526      1
# 1533      2
#          ..
# 70761     1
# 115149    1
# 159000    1
# 164660    1
# 215245    1
# Name: count, Length: 1073, dtype: int64

# %%
print(df.groupby('Alley')['Alley'].value_counts())
sns.countplot(data=df ,x=df['Alley'])
plt.show()
# Out:
# Alley
# Grvl      50
# NA      1369
# Pave      41
# Name: count, dtype: int64

# %%
print(df.groupby('LandContour')['LandContour'].value_counts())
sns.countplot(data=df, x=df['LandContour'])
plt.show()
# Out:
# LandContour
# Bnk      63
# HLS      50
# Low      36
# Lvl    1311
# Name: count, dtype: int64

# %%
print(df.groupby('Utilities')['Utilities'].value_counts())
sns.countplot(data=df, x=df['Utilities'])
plt.show()
# Out:
# Utilities
# AllPub    1459
# NoSeWa       1
# Name: count, dtype: int64

# %%
print(df.groupby('LotConfig')['LotConfig'].value_counts())
sns.countplot(data=df, x=df['LotConfig'])
plt.show()
# Out:
# LotConfig
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Inside     1052
# Name: count, dtype: int64

# %%
print(df.groupby('LandSlope')['LandSlope'].value_counts())
sns.countplot(data=df, x=df['LandSlope'])
plt.show()
# Out:
# LandSlope
# Gtl    1382
# Mod      65
# Sev      13
# Name: count, dtype: int64

# %%
print(df.groupby('Neighborhood')['Neighborhood'].value_counts())
sns.countplot(data=df, x=df['Neighborhood'])
plt.show()
# Out:
# Neighborhood
# Blmngtn     17
# Blueste      2
# BrDale      16
# BrkSide     58
# ClearCr     28
# CollgCr    150
# Crawfor     51
# Edwards    100
# Gilbert     79
# IDOTRR      37
# MeadowV     17
# Mitchel     49
# NAmes      225
# NPkVill      9
# NWAmes      73
# NoRidge     41
# NridgHt     77
# OldTown    113
# SWISU       25
# Sawyer      74
# SawyerW     59
# Somerst     86
# StoneBr     25
# Timber      38
# Veenker     11
# Name: count, dtype: int64

# %%
print(df.groupby('Condition1')['Condition1'].value_counts())
sns.countplot(data=df, x=df['Condition1'])
plt.show()
# Out:
# Condition1
# Artery      48
# Feedr       81
# Norm      1260
# PosA         8
# PosN        19
# RRAe        11
# RRAn        26
# RRNe         2
# RRNn         5
# Name: count, dtype: int64

# %%
print(df.groupby('Condition2')['Condition2'].value_counts())
sns.countplot(data=df, x=df['Condition2'])
plt.show()
# Out:
# Condition2
# Artery       2
# Feedr        6
# Norm      1445
# PosA         1
# PosN         2
# RRAe         1
# RRAn         1
# RRNn         2
# Name: count, dtype: int64

# %%
print(df.groupby('BldgType')['BldgType'].value_counts())
sns.countplot(data=df, x=df['BldgType'])
plt.show()
# Out:
# BldgType
# 1Fam      1220
# 2fmCon      31
# Duplex      52
# Twnhs       43
# TwnhsE     114
# Name: count, dtype: int64

# %%
print(df.groupby('HouseStyle')['HouseStyle'].value_counts())
sns.countplot(data=df, x=df['HouseStyle'])
plt.show()
# Out:
# HouseStyle
# 1.5Fin    154
# 1.5Unf     14
# 1Story    726
# 2.5Fin      8
# 2.5Unf     11
# 2Story    445
# SFoyer     37
# SLvl       65
# Name: count, dtype: int64

# %%
print(df.groupby('OverallQual')['OverallQual'].value_counts())
sns.countplot(data=df, x=df['OverallQual'])
plt.show()
# Out:
# OverallQual
# 1       2
# 2       3
# 3      20
# 4     116
# 5     397
# 6     374
# 7     319
# 8     168
# 9      43
# 10     18
# Name: count, dtype: int64

# %%
print(df.groupby('OverallCond')['OverallCond'].value_counts())
sns.countplot(data=df, x=df['OverallCond'])
plt.show()
# Out:
# OverallCond
# 1      1
# 2      5
# 3     25
# 4     57
# 5    821
# 6    252
# 7    205
# 8     72
# 9     22
# Name: count, dtype: int64

# %%
sns.histplot(data=df, x=df['YearBuilt'])
plt.show()

# %%
sns.histplot(data=df, x=df['YearRemodAdd'])
plt.show()

# %%
print(df.groupby('RoofStyle')['RoofStyle'].value_counts())
sns.countplot(data=df, x=df['RoofStyle'])
plt.show()
# Out:
# RoofStyle
# Flat         13
# Gable      1141
# Gambrel      11
# Hip         286
# Mansard       7
# Shed          2
# Name: count, dtype: int64

# %%
print(df.groupby('RoofMatl')['RoofMatl'].value_counts())
sns.countplot(data=df, x=df['RoofMatl'])
plt.show()
# Out:
# RoofMatl
# ClyTile       1
# CompShg    1434
# Membran       1
# Metal         1
# Roll          1
# Tar&Grv      11
# WdShake       5
# WdShngl       6
# Name: count, dtype: int64

# %%
print(df.groupby('Exterior1st')['Exterior1st'].value_counts())
sns.countplot(data=df, x=df['Exterior1st'])
plt.show()
# Out:
# Exterior1st
# AsbShng     20
# AsphShn      1
# BrkComm      2
# BrkFace     50
# CBlock       1
# CemntBd     61
# HdBoard    222
# ImStucc      1
# MetalSd    220
# Plywood    108
# Stone        2
# Stucco      25
# VinylSd    515
# Wd Sdng    206
# WdShing     26
# Name: count, dtype: int64

# %%
print(df.groupby('Exterior2nd')['Exterior2nd'].value_counts())
sns.countplot(data =df,x=df['Exterior2nd'] )
plt.show()
# Out:
# Exterior2nd
# AsbShng     20
# AsphShn      3
# Brk Cmn      7
# BrkFace     25
# CBlock       1
# CmentBd     60
# HdBoard    207
# ImStucc     10
# MetalSd    214
# Other        1
# Plywood    142
# Stone        5
# Stucco      26
# VinylSd    504
# Wd Sdng    197
# Wd Shng     38
# Name: count, dtype: int64

# %%
print(df.groupby('MasVnrType')['MasVnrType'].value_counts())
sns.countplot(data=df, x=df['MasVnrType'])
plt.show()
# Out:
# MasVnrType
# BrkCmn      15
# BrkFace    445
# None       872
# Stone      128
# Name: count, dtype: int64

# %%
sns.histplot(data=df, x=df['MasVnrArea'], bins=50)
plt.show()

# %%
print(df.groupby('ExterQual')['ExterQual'].value_counts())
sns.countplot(data=df, x=df['ExterQual'])
plt.show()
# Out:
# ExterQual
# Ex     52
# Fa     14
# Gd    488
# TA    906
# Name: count, dtype: int64

# %%
print(df.groupby('ExterCond')['ExterCond'].value_counts())
sns.countplot(data=df, x=df['ExterCond'])
plt.show()
# Out:
# ExterCond
# Ex       3
# Fa      28
# Gd     146
# Po       1
# TA    1282
# Name: count, dtype: int64

# %%
print(df.groupby('Foundation')['Foundation'].value_counts())
sns.countplot(data=df, x=df['Foundation'])
plt.show()
# Out:
# Foundation
# BrkTil    146
# CBlock    634
# PConc     647
# Slab       24
# Stone       6
# Wood        3
# Name: count, dtype: int64

# %%
print(df.groupby('BsmtQual')['BsmtQual'].value_counts())
sns.countplot(data=df, x=df['BsmtQual'])
plt.show()
# Out:
# BsmtQual
# Ex    121
# Fa     35
# Gd    618
# NA     37
# TA    649
# Name: count, dtype: int64

# %%
print(df.groupby('BsmtCond')['BsmtCond'].value_counts())
sns.countplot(data=df, x=df['BsmtCond'])
plt.show()
# Out:
# BsmtCond
# Fa      45
# Gd      65
# NA      37
# Po       2
# TA    1311
# Name: count, dtype: int64

# %%
print(df.groupby('BsmtExposure')['BsmtExposure'].value_counts())
sns.countplot(data=df, x=df['BsmtExposure'])
plt.show()
# Out:
# BsmtExposure
# Av    221
# Gd    134
# Mn    114
# NA     38
# No    953
# Name: count, dtype: int64

# %%
print(df.groupby('BsmtFinType1')['BsmtFinType1'].value_counts())
sns.countplot(data=df, x=df['BsmtFinType1'])
plt.show()
# Out:
# BsmtFinType1
# ALQ    220
# BLQ    148
# GLQ    418
# LwQ     74
# NA      37
# Rec    133
# Unf    430
# Name: count, dtype: int64

# %%
print(df.groupby('BsmtFinSF1')['BsmtFinSF1'].value_counts())
sns.histplot(data=df, x=df['BsmtFinSF1'])
plt.show()
# Out:
# BsmtFinSF1
# 0       467
# 2         1
# 16        9
# 20        5
# 24       12
#        ...
# 1904      1
# 2096      1
# 2188      1
# 2260      1
# 5644      1
# Name: count, Length: 637, dtype: int64

# %%
print(df.groupby('BsmtFinType2')['BsmtFinType2'].value_counts())
sns.countplot(data=df, x=df['BsmtFinType2'])
plt.show()
# Out:
# BsmtFinType2
# ALQ      19
# BLQ      33
# GLQ      14
# LwQ      46
# NA       38
# Rec      54
# Unf    1256
# Name: count, dtype: int64

# %%
print(df.groupby('BsmtFinSF2')['BsmtFinSF2'].value_counts())
sns.histplot(data=df, x=df['BsmtFinSF2'])
plt.show()
# Out:
# BsmtFinSF2
# 0       1293
# 28         1
# 32         1
# 35         1
# 40         1
#         ...
# 1080       1
# 1085       1
# 1120       1
# 1127       1
# 1474       1
# Name: count, Length: 144, dtype: int64

# %%
print(df.groupby('BsmtUnfSF')['BsmtUnfSF'].value_counts())
sns.histplot(data=df, x=df['BsmtUnfSF'])
plt.show()
# Out:
# BsmtUnfSF
# 0       118
# 14        1
# 15        1
# 23        2
# 26        1
#        ...
# 2042      1
# 2046      1
# 2121      1
# 2153      1
# 2336      1
# Name: count, Length: 780, dtype: int64

# %%
print(df.groupby('TotalBsmtSF')['TotalBsmtSF'].value_counts())
sns.histplot(data=df, x=df['TotalBsmtSF'])
plt.show()
# Out:
# TotalBsmtSF
# 0       37
# 105      1
# 190      1
# 264      3
# 270      1
#         ..
# 3094     1
# 3138     1
# 3200     1
# 3206     1
# 6110     1
# Name: count, Length: 721, dtype: int64

# %%
print(df.groupby('Heating')['Heating'].value_counts())
sns.countplot(data=df, x=df['Heating'])
plt.show()
# Out:
# Heating
# Floor       1
# GasA     1428
# GasW       18
# Grav        7
# OthW        2
# Wall        4
# Name: count, dtype: int64

# %%
print(df.groupby('HeatingQC')['HeatingQC'].value_counts())
sns.countplot(data=df, x=df['HeatingQC'])
plt.show()
# Out:
# HeatingQC
# Ex    741
# Fa     49
# Gd    241
# Po      1
# TA    428
# Name: count, dtype: int64

# %%
print(df.groupby('CentralAir')['CentralAir'].value_counts())
sns.countplot(data=df, x=df['CentralAir'])
plt.show()
# Out:
# CentralAir
# N      95
# Y    1365
# Name: count, dtype: int64

# %%
print(df.groupby('Electrical')['Electrical'].value_counts())
sns.countplot(data=df, x=df['Electrical'])
plt.show()
# Out:
# Electrical
# FuseA        94
# FuseF        27
# FuseP         3
# Mix           1
# SBrkr      1334
# Unknown       1
# Name: count, dtype: int64

# %%
print(df.groupby('1stFlrSF')['1stFlrSF'].value_counts())
sns.histplot(data=df, x=df['1stFlrSF'])
plt.show()
# Out:
# 1stFlrSF
# 334     1
# 372     1
# 438     1
# 480     1
# 483     7
#        ..
# 2633    1
# 2898    1
# 3138    1
# 3228    1
# 4692    1
# Name: count, Length: 753, dtype: int64

# %%
print(df.groupby('2ndFlrSF')['2ndFlrSF'].value_counts())
sns.histplot(data=df, x=df['2ndFlrSF'])
plt.show()
# Out:
# 2ndFlrSF
# 0       829
# 110       1
# 167       1
# 192       1
# 208       1
#        ...
# 1611      1
# 1796      1
# 1818      1
# 1872      1
# 2065      1
# Name: count, Length: 417, dtype: int64

# %%
#print(df.groupby('LowQualFinSF')['LowQualFinSF'].value_counts())
sns.histplot(data=df, x=df['LowQualFinSF'])
plt.show()

# %%
#print(df.groupby('GrLivArea')['GrLivArea'].value_counts())
sns.histplot(data=df, x=df['GrLivArea'])
plt.show()

# %%
#print(df.groupby('BsmtFullBath')['BsmtFullBath'].value_counts())
sns.countplot(data=df, x=df['BsmtFullBath'])
plt.show()

# %%
#print(df.groupby('BsmtHalfBath')['BsmtHalfBath'].value_counts())
sns.countplot(data=df, x=df['BsmtHalfBath'])
plt.show()

# %%
#print(df.groupby('FullBath')['FullBath'].value_counts())
sns.countplot(data=df, x=df['FullBath'])
plt.show()

# %%
#print(df.groupby('HalfBath')['HalfBath'].value_counts())
sns.countplot(data=df, x=df['HalfBath'])
plt.show()

# %%
#print(df.groupby('HalfBath')['HalfBath'].value_counts())
sns.countplot(data=df, x=df['BedroomAbvGr'])
plt.show()

# %%
print(df.groupby('KitchenAbvGr')['KitchenAbvGr'].value_counts())
sns.countplot(data=df, x=df['KitchenAbvGr'])
plt.show()
# Out:
# KitchenAbvGr
# 0       1
# 1    1392
# 2      65
# 3       2
# Name: count, dtype: int64

# %%
print(df.groupby('KitchenQual')['KitchenQual'].value_counts())
sns.countplot(data=df, x=df['KitchenQual'])
plt.show()
# Out:
# KitchenQual
# Ex    100
# Fa     39
# Gd    586
# TA    735
# Name: count, dtype: int64

# %%
print(df.groupby('TotRmsAbvGrd')['TotRmsAbvGrd'].value_counts())
sns.histplot(data=df, x=df['TotRmsAbvGrd'])
plt.show()
# Out:
# TotRmsAbvGrd
# 2       1
# 3      17
# 4      97
# 5     275
# 6     402
# 7     329
# 8     187
# 9      75
# 10     47
# 11     18
# 12     11
# 14      1
# Name: count, dtype: int64

# %%
print(df.groupby('Functional')['Functional'].value_counts())
sns.countplot(data=df, x=df['Functional'])
plt.show()
# Out:
# Functional
# Maj1      14
# Maj2       5
# Min1      31
# Min2      34
# Mod       15
# Sev        1
# Typ     1360
# Name: count, dtype: int64

# %%
print(df.groupby('Fireplaces')['Fireplaces'].value_counts())
sns.countplot(data=df, x=df['Fireplaces'])
plt.show()
# Out:
# Fireplaces
# 0    690
# 1    650
# 2    115
# 3      5
# Name: count, dtype: int64

# %%
print(df.groupby('FireplaceQu')['FireplaceQu'].value_counts())
sns.countplot(data=df, x=df['FireplaceQu'])
plt.show()
# Out:
# FireplaceQu
# Ex     24
# Fa     33
# Gd    380
# NA    690
# Po     20
# TA    313
# Name: count, dtype: int64

# %%
print(df.groupby('GarageType')['GarageType'].value_counts())
sns.countplot(data=df, x=df['GarageType'])
plt.show()
# Out:
# GarageType
# 2Types       6
# Attchd     870
# Basment     19
# BuiltIn     88
# CarPort      9
# Detchd     387
# NA          81
# Name: count, dtype: int64

# %%
print(df.groupby('GarageYrBlt')['GarageYrBlt'].value_counts())
sns.histplot(data=df, x=df['GarageYrBlt'])
plt.show()
# Out:
# GarageYrBlt
# 1900.0     1
# 1906.0     1
# 1908.0     1
# 1910.0     3
# 1914.0     2
#           ..
# 2006.0    59
# 2007.0    49
# 2008.0    29
# 2009.0    21
# 2010.0     3
# Name: count, Length: 97, dtype: int64

# %%
print(df.groupby('GarageFinish')['GarageFinish'].value_counts())
sns.countplot(data=df, x=df['GarageFinish'])
plt.show()
# Out:
# GarageFinish
# Fin    352
# NA      81
# RFn    422
# Unf    605
# Name: count, dtype: int64

# %%
print(df.groupby('GarageCars')['GarageCars'].value_counts())
sns.countplot(data=df, x=df['GarageCars'])
plt.show()
# Out:
# GarageCars
# 0     81
# 1    369
# 2    824
# 3    181
# 4      5
# Name: count, dtype: int64

# %%
print(df.groupby('GarageArea')['GarageArea'].value_counts())
sns.histplot(data=df, x=df['GarageArea'])
plt.show()
# Out:
# GarageArea
# 0       81
# 160      2
# 164      1
# 180      9
# 186      1
#         ..
# 1220     1
# 1248     1
# 1356     1
# 1390     1
# 1418     1
# Name: count, Length: 441, dtype: int64

# %%
print(df.groupby('GarageQual')['GarageQual'].value_counts())
sns.countplot(data=df, x=df['GarageQual'])
plt.show()
# Out:
# GarageQual
# Ex       3
# Fa      48
# Gd      14
# NA      81
# Po       3
# TA    1311
# Name: count, dtype: int64

# %%
print(df.groupby('GarageCond')['GarageCond'].value_counts())
sns.countplot(data=df, x=df['GarageCond'])
plt.show()
# Out:
# GarageCond
# Ex       2
# Fa      35
# Gd       9
# NA      81
# Po       7
# TA    1326
# Name: count, dtype: int64

# %%
print(df.groupby('PavedDrive')['PavedDrive'].value_counts())
sns.countplot(data=df, x=df['PavedDrive'])
plt.show()
# Out:
# PavedDrive
# N      90
# P      30
# Y    1340
# Name: count, dtype: int64

# %%
print(df.groupby('WoodDeckSF')['WoodDeckSF'].value_counts())
sns.histplot(data=df, x=df['WoodDeckSF'])
plt.show()
# Out:
# WoodDeckSF
# 0      761
# 12       2
# 24       2
# 26       2
# 28       2
#       ...
# 668      1
# 670      1
# 728      1
# 736      1
# 857      1
# Name: count, Length: 274, dtype: int64

# %%
print(df.groupby('OpenPorchSF')['OpenPorchSF'].value_counts())
sns.histplot(data=df, x=df['OpenPorchSF'])
plt.show()
# Out:
# OpenPorchSF
# 0      656
# 4        1
# 8        1
# 10       1
# 11       1
#       ...
# 406      1
# 418      1
# 502      1
# 523      1
# 547      1
# Name: count, Length: 202, dtype: int64

# %%
print(df.groupby('EnclosedPorch')['EnclosedPorch'].value_counts())
sns.histplot(data=df, x=df['EnclosedPorch'])
plt.show()
# Out:
# EnclosedPorch
# 0      1252
# 19        1
# 20        1
# 24        1
# 30        1
#        ...
# 301       1
# 318       1
# 330       1
# 386       1
# 552       1
# Name: count, Length: 120, dtype: int64

# %%
print(df.groupby('3SsnPorch')['3SsnPorch'].value_counts())
sns.histplot(data=df, x=df['3SsnPorch'])
plt.show()
# Out:
# 3SsnPorch
# 0      1436
# 23        1
# 96        1
# 130       1
# 140       1
# 144       2
# 153       1
# 162       1
# 168       3
# 180       2
# 182       1
# 196       1
# 216       2
# 238       1
# 245       1
# 290       1
# 304       1
# 320       1
# 407       1
# 508       1
# Name: count, dtype: int64

# %%
print(df.groupby('ScreenPorch')['ScreenPorch'].value_counts())
sns.histplot(data=df, x=df['ScreenPorch'])
plt.show()
# Out:
# ScreenPorch
# 0      1344
# 40        1
# 53        1
# 60        1
# 63        1
#        ...
# 385       1
# 396       1
# 410       1
# 440       1
# 480       1
# Name: count, Length: 76, dtype: int64

# %%
print(df.groupby('PoolArea')['PoolArea'].value_counts())
sns.histplot(data=df, x=df['PoolArea'])
plt.show()
# Out:
# PoolArea
# 0      1453
# 480       1
# 512       1
# 519       1
# 555       1
# 576       1
# 648       1
# 738       1
# Name: count, dtype: int64

# %%
print(df.groupby('PoolQC')['PoolQC'].value_counts())
sns.countplot(data=df, x=df['PoolQC'])
plt.show()
# Out:
# PoolQC
# Ex       2
# Fa       2
# Gd       3
# NA    1453
# Name: count, dtype: int64

# %%
print(df.groupby('Fence')['Fence'].value_counts())
sns.countplot(data=df, x=df['Fence'])
plt.show()
# Out:
# Fence
# GdPrv      59
# GdWo       54
# MnPrv     157
# MnWw       11
# NA       1179
# Name: count, dtype: int64

# %%
print(df.groupby('MiscFeature')['MiscFeature'].value_counts())
sns.countplot(data=df, x=df['MiscFeature'])
plt.show()
# Out:
# MiscFeature
# Gar2       2
# NA      1406
# Othr       2
# Shed      49
# TenC       1
# Name: count, dtype: int64

# %%
print(df.groupby('MiscVal')['MiscVal'].value_counts())
sns.histplot(data=df, x=df['MiscVal'])
plt.show()
# Out:
# MiscVal
# 0        1408
# 54          1
# 350         1
# 400        11
# 450         4
# 480         2
# 500         8
# 560         1
# 600         4
# 620         1
# 700         5
# 800         1
# 1150        1
# 1200        2
# 1300        1
# 1400        1
# 2000        4
# 2500        1
# 3500        1
# 8300        1
# 15500       1
# Name: count, dtype: int64

# %%
print(df.groupby('MoSold')['MoSold'].value_counts())
sns.countplot(data=df, x=df['MoSold'])
plt.show()
# Out:
# MoSold
# 1      58
# 2      52
# 3     106
# 4     141
# 5     204
# 6     253
# 7     234
# 8     122
# 9      63
# 10     89
# 11     79
# 12     59
# Name: count, dtype: int64

# %%
print(df.groupby('YrSold')['YrSold'].value_counts())
sns.countplot(data=df, x=df['YrSold'])
plt.show()
# Out:
# YrSold
# 2006    314
# 2007    329
# 2008    304
# 2009    338
# 2010    175
# Name: count, dtype: int64

# %%
print(df.groupby('SaleType')['SaleType'].value_counts())
sns.countplot(data=df, x=df['SaleType'])
plt.show()
# Out:
# SaleType
# COD        43
# CWD         4
# Con         2
# ConLD       9
# ConLI       5
# ConLw       5
# New       122
# Oth         3
# WD       1267
# Name: count, dtype: int64

# %%
print(df.groupby('SaleCondition')['SaleCondition'].value_counts())
sns.countplot(data=df, x=df['SaleCondition'])
plt.show()
# Out:
# SaleCondition
# Abnorml     101
# AdjLand       4
# Alloca       12
# Family       20
# Normal     1198
# Partial     125
# Name: count, dtype: int64

# %%
print(df.groupby('SalePrice')['SalePrice'].value_counts())
sns.histplot(data=df, x=df['SalePrice'])
plt.show()
# Out:
# SalePrice
# 34900     1
# 35311     1
# 37900     1
# 39300     1
# 40000     1
#          ..
# 582933    1
# 611657    1
# 625000    1
# 745000    1
# 755000    1
# Name: count, Length: 663, dtype: int64

# %%
#how price with different features

# %%
col1 = df.groupby('MSSubClass', as_index=False)['SalePrice'].mean()
print(col1)
sns.barplot(data=col1, x = 'MSSubClass', y= 'SalePrice')
plt.show()
# Out:
#     MSSubClass      SalePrice
# 0           20  185224.811567
# 1           30   95829.724638
# 2           40  156125.000000
# 3           45  108591.666667
# 4           50  143302.972222
# 5           60  239948.501672
# 6           70  166772.416667
# 7           75  192437.500000
# 8           80  169736.551724
# 9           85  147810.000000
# 10          90  133541.076923
# 11         120  200779.080460
# 12         160  138647.380952
# 13         180  102300.000000
# 14         190  129613.333333

# %%
sns.boxplot(data=df, x='MSSubClass', y= 'SalePrice')
plt.show()

# %%
sns.boxplot(data=df, x='MSZoning' , y= 'SalePrice')
plt.show()

# %%
print(df['Street'].value_counts())
sns.boxplot(data=df , x='Street', y='SalePrice')
plt.show()
# Out:
# Street
# Pave    1454
# Grvl       6
# Name: count, dtype: int64

# %%
print(df['Alley'].value_counts())
sns.boxplot(data=df, x='Alley', y='SalePrice')
plt.show()
# Out:
# Alley
# NA      1369
# Grvl      50
# Pave      41
# Name: count, dtype: int64

# %%
print(df['LotShape'].value_counts())
sns.boxplot(data=df , x='LotShape', y= 'SalePrice')
plt.show()
# Out:
# LotShape
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: count, dtype: int64

# %%
print(df['LandContour'].value_counts())
sns.boxplot(data=df, x='LandContour', y='SalePrice')
plt.show()
# Out:
# LandContour
# Lvl    1311
# Bnk      63
# HLS      50
# Low      36
# Name: count, dtype: int64

# %%
print(df['Utilities'].value_counts())
sns.boxplot(data=df, x='Utilities',y='SalePrice')
plt.show()
# Out:
# Utilities
# AllPub    1459
# NoSeWa       1
# Name: count, dtype: int64

# %%
print(df['LotConfig'].value_counts())
sns.boxplot(data=df , x='LotConfig', y='SalePrice')
plt.show()
# Out:
# LotConfig
# Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Name: count, dtype: int64

# %%
print(df['LandSlope'].value_counts())
sns.boxplot(data=df, x='LandSlope', y='SalePrice')
plt.show()
# Out:
# LandSlope
# Gtl    1382
# Mod      65
# Sev      13
# Name: count, dtype: int64

# %%
# order = (
#     df.groupby('Neighborhood')['SalePrice']
#       .median()
#       .sort_values()
#       .index
# )

print(df['Neighborhood'].value_counts())
sns.boxplot(data=df, x='Neighborhood', y='SalePrice')
plt.xticks(rotation=90)
plt.show()
# Out:
# Neighborhood
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# Timber      38
# IDOTRR      37
# ClearCr     28
# SWISU       25
# StoneBr     25
# Blmngtn     17
# MeadowV     17
# BrDale      16
# Veenker     11
# NPkVill      9
# Blueste      2
# Name: count, dtype: int64

# %%
print(df['Condition1'].value_counts())
sns.boxplot(data=df, x='Condition1', y='SalePrice')
plt.show()
# Out:
# Condition1
# Norm      1260
# Feedr       81
# Artery      48
# RRAn        26
# PosN        19
# RRAe        11
# PosA         8
# RRNn         5
# RRNe         2
# Name: count, dtype: int64

# %%
print(df['Condition2'].value_counts())
sns.boxplot(data=df , x='Condition2', y='SalePrice')
plt.show()
# Out:
# Condition2
# Norm      1445
# Feedr        6
# Artery       2
# RRNn         2
# PosN         2
# PosA         1
# RRAn         1
# RRAe         1
# Name: count, dtype: int64

# %%
print(df['BldgType'].value_counts())
sns.boxplot(data=df, x='BldgType', y='SalePrice')
plt.show()
# Out:
# BldgType
# 1Fam      1220
# TwnhsE     114
# Duplex      52
# Twnhs       43
# 2fmCon      31
# Name: count, dtype: int64

# %%
print(df['HouseStyle'].value_counts())
sns.boxplot(data=df, x= 'HouseStyle', y='SalePrice')
plt.show()
# Out:
# HouseStyle
# 1Story    726
# 2Story    445
# 1.5Fin    154
# SLvl       65
# SFoyer     37
# 1.5Unf     14
# 2.5Unf     11
# 2.5Fin      8
# Name: count, dtype: int64

# %%
print(df['OverallQual'].value_counts())
sns.boxplot(data=df , x='OverallQual', y='SalePrice')
plt.show()
# Out:
# OverallQual
# 5     397
# 6     374
# 7     319
# 8     168
# 4     116
# 9      43
# 3      20
# 10     18
# 2       3
# 1       2
# Name: count, dtype: int64

# %%
print(df['OverallCond'].value_counts())
sns.boxplot(data=df ,x='OverallCond', y='SalePrice')
plt.show()
# Out:
# OverallCond
# 5    821
# 6    252
# 7    205
# 8     72
# 4     57
# 3     25
# 9     22
# 2      5
# 1      1
# Name: count, dtype: int64

# %%
print(df['YearBuilt'].value_counts())
sns.histplot(data=df ,x='YearBuilt', y='SalePrice')
plt.show()
# Out:
# YearBuilt
# 2006    67
# 2005    64
# 2004    54
# 2007    49
# 2003    45
#         ..
# 1875     1
# 1911     1
# 1917     1
# 1872     1
# 1905     1
# Name: count, Length: 112, dtype: int64

# %%
print(df['YearRemodAdd'].value_counts())
sns.histplot(data=df, x='YearRemodAdd', y='SalePrice')
plt.show()
# Out:
# YearRemodAdd
# 1950    178
# 2006     97
# 2007     76
# 2005     73
# 2004     62
#        ...
# 2010      6
# 1983      5
# 1952      5
# 1986      5
# 1951      4
# Name: count, Length: 61, dtype: int64

# %%
print(df['RoofStyle'].value_counts())
sns.boxplot(data=df, x='RoofStyle', y='SalePrice')
plt.show()
# Out:
# RoofStyle
# Gable      1141
# Hip         286
# Flat         13
# Gambrel      11
# Mansard       7
# Shed          2
# Name: count, dtype: int64

# %%
print(df['RoofMatl'].value_counts())
sns.boxplot(data=df, x='RoofMatl', y='SalePrice')
plt.show()
# Out:
# RoofMatl
# CompShg    1434
# Tar&Grv      11
# WdShngl       6
# WdShake       5
# Metal         1
# Membran       1
# Roll          1
# ClyTile       1
# Name: count, dtype: int64

# %%
print(df['Exterior1st'].value_counts())
sns.boxplot(data=df, x='Exterior1st', y='SalePrice')
plt.xticks(rotation=90)
plt.show()
# Out:
# Exterior1st
# VinylSd    515
# HdBoard    222
# MetalSd    220
# Wd Sdng    206
# Plywood    108
# CemntBd     61
# BrkFace     50
# WdShing     26
# Stucco      25
# AsbShng     20
# BrkComm      2
# Stone        2
# AsphShn      1
# ImStucc      1
# CBlock       1
# Name: count, dtype: int64

# %%
print(df['Exterior2nd'].value_counts())
sns.boxplot(data=df, x='Exterior2nd', y='SalePrice')
plt.xticks(rotation=90)
plt.show()
# Out:
# Exterior2nd
# VinylSd    504
# MetalSd    214
# HdBoard    207
# Wd Sdng    197
# Plywood    142
# CmentBd     60
# Wd Shng     38
# Stucco      26
# BrkFace     25
# AsbShng     20
# ImStucc     10
# Brk Cmn      7
# Stone        5
# AsphShn      3
# Other        1
# CBlock       1
# Name: count, dtype: int64

# %%
print(df['MasVnrType'].value_counts())
sns.boxplot(data=df , x='MasVnrType', y='SalePrice')
plt.show()
# Out:
# MasVnrType
# None       872
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: count, dtype: int64

# %%
print(df['MasVnrArea'].value_counts())
sns.scatterplot(data=df, x='MasVnrArea', y='SalePrice')
plt.show()
# Out:
# MasVnrArea
# 0.0      869
# 108.0      8
# 72.0       8
# 180.0      8
# 16.0       7
#         ...
# 426.0      1
# 96.0       1
# 438.0      1
# 194.0      1
# 119.0      1
# Name: count, Length: 327, dtype: int64

# %%
print(df['ExterQual'].value_counts())
sns.boxplot(data=df, x='ExterQual', y='SalePrice')
plt.show()
# Out:
# ExterQual
# TA    906
# Gd    488
# Ex     52
# Fa     14
# Name: count, dtype: int64

# %%
print(df['ExterCond'].value_counts())
sns.boxplot(data=df , x='ExterCond', y='SalePrice')
plt.show()
# Out:
# ExterCond
# TA    1282
# Gd     146
# Fa      28
# Ex       3
# Po       1
# Name: count, dtype: int64

# %%
print(df['Foundation'].value_counts())
sns.boxplot(data=df, x='Foundation', y='SalePrice')
plt.show()
# Out:
# Foundation
# PConc     647
# CBlock    634
# BrkTil    146
# Slab       24
# Stone       6
# Wood        3
# Name: count, dtype: int64

# %%
print(df['BsmtQual'].value_counts())
sns.boxplot(data=df, x='BsmtQual', y='SalePrice')
plt.show()
# Out:
# BsmtQual
# TA    649
# Gd    618
# Ex    121
# NA     37
# Fa     35
# Name: count, dtype: int64

# %%
print(df['BsmtCond'].value_counts())
sns.boxplot(data=df, x='BsmtCond', y='SalePrice')
plt.show()
# Out:
# BsmtCond
# TA    1311
# Gd      65
# Fa      45
# NA      37
# Po       2
# Name: count, dtype: int64

# %%
print(df['BsmtExposure'].value_counts())
sns.boxplot(data=df, x='BsmtExposure', y='SalePrice')
plt.show()
# Out:
# BsmtExposure
# No    953
# Av    221
# Gd    134
# Mn    114
# NA     38
# Name: count, dtype: int64

# %%
print(df['BsmtFinType1'].value_counts())
sns.boxplot(data=df, x='BsmtFinType1', y='SalePrice')
plt.show()
# Out:
# BsmtFinType1
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# NA      37
# Name: count, dtype: int64

# %%
print(df['BsmtFinSF1'].value_counts())
sns.histplot(data=df, x='BsmtFinSF1', y='SalePrice')
plt.show()
# Out:
# BsmtFinSF1
# 0       467
# 24       12
# 16        9
# 686       5
# 936       5
#        ...
# 203       1
# 309       1
# 408       1
# 1282      1
# 548       1
# Name: count, Length: 637, dtype: int64

# %%
print(df['BsmtFinType2'].value_counts())
sns.boxplot(data=df, x='BsmtFinType2', y='SalePrice')
plt.show()
# Out:
# BsmtFinType2
# Unf    1256
# Rec      54
# LwQ      46
# NA       38
# BLQ      33
# ALQ      19
# GLQ      14
# Name: count, dtype: int64

# %%
print(df['BsmtFinSF2'].value_counts())
sns.histplot(data=df, x='BsmtFinSF2', y='SalePrice')
plt.show()
# Out:
# BsmtFinSF2
# 0       1293
# 180        5
# 374        3
# 93         2
# 287        2
#         ...
# 872        1
# 110        1
# 627        1
# 163        1
# 1029       1
# Name: count, Length: 144, dtype: int64

# %%
print(df['BsmtUnfSF'].value_counts())
sns.histplot(data=df, x='BsmtUnfSF', y='SalePrice')
plt.show()
# Out:
# BsmtUnfSF
# 0       118
# 728       9
# 384       8
# 300       7
# 572       7
#        ...
# 1252      1
# 709       1
# 734       1
# 503       1
# 616       1
# Name: count, Length: 780, dtype: int64

# %%
print(df['TotalBsmtSF'].value_counts())
sns.scatterplot(data=df, x='TotalBsmtSF', y='SalePrice')
plt.show()
# Out:
# TotalBsmtSF
# 0       37
# 864     35
# 672     17
# 912     15
# 1040    14
#         ..
# 1525     1
# 482      1
# 1542     1
# 839      1
# 1286     1
# Name: count, Length: 721, dtype: int64

# %%
print(df['Heating'].value_counts())
sns.boxplot(data=df, x='Heating', y='SalePrice')
plt.show()
# Out:
# Heating
# GasA     1428
# GasW       18
# Grav        7
# Wall        4
# OthW        2
# Floor       1
# Name: count, dtype: int64
